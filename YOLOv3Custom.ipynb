# %%
to_run = True

# %%
if to_run:
  # !git clone https://github.com/rizwan19/TrainYourOwnYOLO
  # %cd TrainYourOwnYOLO
  to_run = False
# Out:
# Cloning into 'TrainYourOwnYOLO'...
# remote: Enumerating objects: 123, done.
# remote: Counting objects: 100% (123/123), done.
# remote: Compressing objects: 100% (122/122), done.
# remote: Total 673 (delta 56), reused 0 (delta 0), pack-reused 550
# Receiving objects: 100% (673/673), 83.28 MiB | 41.52 MiB/s, done.
# Resolving deltas: 100% (131/131), done.
# /content/TrainYourOwnYOLO

# %%
# !python Minimal_Example.py
# Out:
# ...
#
# | |                            #                    | 7533 Elapsed Time: 0:00:02
# Downloaded Pretrained Weights in 4.2 seconds
#
# Detecting Cat Faces by calling:
#
#  python /content/TrainYourOwnYOLO/3_Inference/Detector.py --input_path /content/TrainYourOwnYOLO/Data/Source_Images/Test_Images --classes /content/TrainYourOwnYOLO/Data/Model_Weights/data_classes.txt --output /content/TrainYourOwnYOLO/Data/Source_Images/Test_Image_Detection_Results --yolo_model /content/TrainYourOwnYOLO/Data/Model_Weights/trained_weights_final.h5 --box_file /content/TrainYourOwnYOLO/Data/Source_Images/Test_Image_Detection_Results/Detection_Results.csv --anchors /content/TrainYourOwnYOLO/2_Training/src/keras_yolo3/model_data/yolo_anchors.txt --file_types .jpg .jpeg .png
#
# 2020-10-03 16:59:47.007185: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# ...

# %%
# %cd 2_Training
# !python Download_and_Convert_YOLO_weights.py
# Out:
# /content/TrainYourOwnYOLO/2_Training
#
# ...
#
# | |                        #                        | 7568 Elapsed Time: 0:00:02
# Downloaded Raw yolov3.weights in 3.7 seconds
#
# 2020-10-03 17:00:30.818770: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# Loading weights.
# Weights Header:  0 2 0 [32013312]
# Parsing Darknet config.
# Creating Keras model.
# Parsing section net_0
# Parsing section convolutional_0
# conv2d bn leaky (3, 3, 3, 32)
# 2020-10-03 17:00:32.201109: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-10-03 17:00:32.240381: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...

# %%
# !python Train_YOLO.py
# Out:
# 2020-10-03 17:00:45.478168: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-10-03 17:00:46.905437: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-10-03 17:00:46.941065: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-03 17:00:46.942637: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.73GiB deviceMemoryBandwidth: 298.08GiB/s
# 2020-10-03 17:00:46.942703: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# ...

# %%
# %cd ..
# Out:
# /content/TrainYourOwnYOLO

# %%
# %cd 3_Inference/
# Out:
# /content/TrainYourOwnYOLO/3_Inference

# %%
# !python Detector.py
# Out:
# 2020-10-03 17:09:33.412428: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-10-03 17:09:35.388087: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-10-03 17:09:35.430164: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-03 17:09:35.430745: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.73GiB deviceMemoryBandwidth: 298.08GiB/s
# 2020-10-03 17:09:35.430795: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# ...
